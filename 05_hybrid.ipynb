# %% [markdown]
# # Library

# %%
import os
import re
import random
import itertools
import platform
import multiprocessing
import multiprocessing.dummy
import logging
import inspect
from typing import List
from datetime import datetime

import jieba
import nltk
import faiss
import numpy as np
import pandas as pd
import sacrebleu
import regex
from sacrebleu import corpus_bleu

# %%
print('Python version:', platform.python_version())
print('Jieba version', jieba.__version__)
print('NLTK version:', nltk.__version__)
print('Numpy version:', np.__version__)
print('Pandas version:', pd.__version__)
print('Sacrebleu version:', sacrebleu.__version__)
print('Regex version:', regex.__version__)
# Out:
# Python version: 3.8.3
# Jieba version 0.42.1
# NLTK version: 3.5
# Numpy version: 1.19.0
# Pandas version: 1.0.5
# Sacrebleu version: 1.4.12
# Regex version: 2.5.64

# %%
if hasattr(faiss, 'StandardGpuResources'):
    print('faiss-gpu detected!')
else:
    print('faiss-cpu detected!')
# Out:
# faiss-gpu detected!

# %%
SEED = 42

os.environ['PYTHONHASHSEED']=str(SEED)
random.seed(SEED)
np.random.seed(SEED)

# %%
OTHERS_PATTERN: re.Pattern = regex.compile(r'\p{So}')

START_DATETIME = str(datetime.now())
logging.basicConfig(filename=f'log_{START_DATETIME}.log',level=logging.DEBUG)

DIMENSION = 300
K = 5
RES = faiss.StandardGpuResources()

CO = faiss.GpuClonerOptions()
CO.useFloat16 = False
CO.usePrecomputed = False
CO.indicesOptions = faiss.INDICES_CPU

# %% [markdown]
# # Vector
#
#  Perform nearest neighbors precomputation with all source tokens, so translation speed would be very fast

# %%
def load_fasttext_embedding(filepath):
    word_index = 0
    word2id = {}
    id2word = {}
    embedding = []

    with open(filepath, 'r', encoding='utf-8', newline='\n', errors='ignore') as f:
        for i, line in enumerate(f):
            if i == 0:
                header = line.split()
                assert len(header) == 2
                assert DIMENSION == int(header[1])
                embedding = np.empty(
                    (int(header[0]), int(header[1])),
                    dtype=np.float32
                )
            else:
                word, word_vector = line.rstrip().split(' ', 1)
                word_vector = np.fromstring(word_vector, sep=' ')

                word2id[word] = word_index
                id2word[word_index] = word
                embedding[i-1] = word_vector[None]
                word_index += 1

    return {
        'word2id'   : word2id,
        'id2word'   : id2word,
        'embedding' : embedding
    }

# %%
vec_ours_en = load_fasttext_embedding('./data/muse/debug/whw5r77gaz/vectors-en.txt')
vec_ours_zh = load_fasttext_embedding('./data/muse/debug/whw5r77gaz/vectors-zh.txt')

vec_wiki_en = load_fasttext_embedding('./data/wikivec/wiki.en.align.vec')
vec_wiki_zh = load_fasttext_embedding('./data/wikivec/wiki.zh.align.vec')

# %%
def create_index(distance, src, tgt):
    if distance == 'IP':
        index = faiss.IndexFlatIP(DIMENSION)
    elif distance == 'L2':
        index = faiss.IndexFlatL2(DIMENSION)
    else:
        index = faiss.IndexFlatIP(DIMENSION)

    index.add(tgt)
    index = faiss.index_cpu_to_gpu(RES, 0, index)

    src2trg_dist, src2trg_id = index.search(src, K)

    return {
        'index'         : index,
        'distance_type' : distance,
        'src2trg_dist'  : src2trg_dist,
        'src2trg_id'    : src2trg_id
    }

# %%
index_ours_ip = create_index('IP', vec_ours_zh['embedding'], vec_ours_en['embedding'])
# index_ours_l2 = create_index('L2', vec_ours_zh['embedding'], vec_ours_en['embedding'])

index_wiki_ip = create_index('IP', vec_wiki_zh['embedding'], vec_wiki_en['embedding'])
# index_wiki_l2 = create_index('L2', vec_wiki_zh['embedding'], vec_wiki_en['embedding'])

# %% [markdown]
# # Check sanity

# %%
def check_sanity(index, vec_trg):
    nearest_dist, nearest_id = index['index'].search(vec_trg['embedding'][1000:1010], K)
    words = [vec_trg['id2word'][i] for i in range(1000, 1010)]
    for i in range(len(words)):
        word = words[i]
        print('Word :', word)

        # word_id = vec_trg['word2id'][word]
        nearest_words = [vec_trg['id2word'][nearest_id[i, j]] for j in range(K)]
        nearest_words_dist = nearest_dist[i]

        print('Nearest words:')
        for i in range(K):
            print(f'{nearest_words[i]} ({nearest_words_dist[i]})')
        print('='*60)

# %%
check_sanity(index_ours_ip, vec_ours_en)
# check_sanity(index_ours_l2, vec_ours_en)

check_sanity(index_wiki_ip, vec_wiki_en)
# check_sanity(index_wiki_l2, vec_wiki_en)
# Out:
# Word : wars
# Nearest words:
# wars (33.9265022277832)
# warfare (26.067710876464844)
# jedi (23.048994064331055)
# kylo (20.80528450012207)
# vader (20.708839416503906)
# ============================================================
# Word : lather
# Nearest words:
# lather (24.970096588134766)
# goop (19.940879821777344)
# flog (17.8062686920166)
# welt (17.789745330810547)
# slash (16.381572723388672)
# ============================================================
# Word : therapy
# Nearest words:
# therapy (40.570106506347656)
# theraphy (23.68070411682129)
# therape (22.41028594970703)
# kidsafe (21.02881622314453)
# mesotherapy (19.31230354309082)
# ============================================================
# Word : drop
# Nearest words:
# drop (25.409725189208984)
# drib (16.737855911254883)
# dangle (16.11564826965332)
# drop-off (15.995134353637695)
# driblet (15.969258308410645)
# ============================================================
# Word : like
# Nearest words:
# like (28.236927032470703)
# ilk (27.70448875427246)
# alike (23.638751983642578)
# comparable (22.66981315612793)
# similar (21.006755828857422)
# ============================================================
# Word : j
# Nearest words:
# j (37.8682746887207)
# joule (35.87204360961914)
# js (19.0262393951416)
# ruin (9.969573974609375)
# dice (9.537631034851074)
# ============================================================
# Word : slingbag
# Nearest words:
# slingbag (36.1331787109375)
# slingbagbag (25.698755264282227)
# slingbags (25.36909294128418)
# hangbag (21.854751586914062)
# toteslingbag (21.57464599609375)
# ============================================================
# Word : mac
# Nearest words:
# mac (39.4156379699707)
# mackintosh (37.23355484008789)
# macintosh (37.10185623168945)
# mack (34.53278732299805)
# macki (21.80196189880371)
# ============================================================
# Word : addition
# Nearest words:
# addition (24.37088394165039)
# summation (23.53346824645996)
# asset (23.51259422302246)
# positive (20.776681900024414)
# plus (17.569658279418945)
# ============================================================
# Word : purpose
# Nearest words:
# purpose (23.432939529418945)
# purport (19.704912185668945)
# propose (17.847421646118164)
# intent (17.027055740356445)
# intention (15.97573184967041)
# ============================================================
# Word : placed
# Nearest words:
# placed (0.9999729990959167)
# placing (0.7686948180198669)
# placed, (0.609352171421051)
# placement (0.5943906903266907)
# #placed (0.5386166572570801)
# ============================================================
# Word : child
# Nearest words:
# child (0.9999997615814209)
# children (0.7058509588241577)
# infant (0.6844779253005981)
# child, (0.6829380393028259)
# parents (0.6806468963623047)
# ============================================================
# Word : perhaps
# Nearest words:
# perhaps (1.0000157356262207)
# …perhaps (0.8205581307411194)
# perhapse (0.7731969356536865)
# perhaps, (0.761385977268219)
# perhapses (0.7402923107147217)
# ============================================================
# Word : idea
# Nearest words:
# idea (1.0000368356704712)
# notion (0.7325024604797363)
# ideas (0.7190083265304565)
# concept (0.6729167699813843)
# thinking (0.6579368710517883)
# ============================================================
# Word : foreign
# Nearest words:
# foreign (0.9999338388442993)
# —foreign (0.794177770614624)
# foreigns (0.769899845123291)
# ‘foreign (0.7600327134132385)
# #foreign (0.7190923690795898)
# ============================================================
# Word : municipality
# Nearest words:
# municipality (0.9999263882637024)
# municipality, (0.9191739559173584)
# #municipality (0.9149118065834045)
# municipalite (0.8569221496582031)
# minicipality (0.8536496162414551)
# ============================================================
# Word : isn
# Nearest words:
# isn (0.9999806880950928)
# doesn (0.8244986534118652)
# shouldn (0.816365122795105)
# wouldn (0.8076133728027344)
# really (0.7968523502349854)
# ============================================================
# Word : register
# Nearest words:
# register (1.000016689300537)
# registery (0.7127357125282288)
# registed (0.7074697017669678)
# bulkregister (0.6851056814193726)
# registern (0.6840051412582397)
# ============================================================
# Word : eight
# Nearest words:
# eight (0.9999337196350098)
# six (0.9474833011627197)
# five (0.9281997680664062)
# seven (0.9159700274467468)
# nine (0.9117922782897949)
# ============================================================
# Word : problems
# Nearest words:
# problems (1.0000288486480713)
# problems— (0.8419852256774902)
# problems, (0.8332198858261108)
# problem (0.8201794028282166)
# problems… (0.8037514686584473)
# ============================================================

# %% [markdown]
# # Check average top-1 index distance

# %%
dist_wiki = np.empty((len(index_wiki_ip['src2trg_dist'])))
for i in range(len(index_wiki_ip['src2trg_dist'])):
    dist_wiki[i] = index_wiki_ip['src2trg_dist'][i][0]

# %%
dist_wiki_sr = pd.Series(dist_wiki)
dist_wiki_sr.describe()
# Out:
# count    332647.000000
# mean          0.262980
# std           0.123026
# min           0.025104
# 25%           0.155658
# 50%           0.238525
# 75%           0.370603
# max           0.702280
# dtype: float64

# %%
dist_ours = np.empty((len(index_ours_ip['src2trg_dist'])))
for i in range(len(index_ours_ip['src2trg_dist'])):
    dist_ours[i] = index_ours_ip['src2trg_dist'][i][0]

# %%
dist_ours_sr = pd.Series(dist_ours)
dist_ours_sr.describe()
# Out:
# count    309334.000000
# mean          8.664581
# std           3.561491
# min           2.586657
# 25%           6.146866
# 50%           7.619271
# 75%          10.336281
# max          43.770702
# dtype: float64

# %% [markdown]
# # Dataset

# %%
val_en = pd.read_csv('./data/csv/dev_en.csv')
val_en = val_en['translation_output']

val_tcn = pd.read_csv('./data/csv/dev_tcn.csv', usecols=['text'])
val_tcn = val_tcn['text']
val_tcn = val_tcn.apply(lambda t:OTHERS_PATTERN.sub(' ', t))

test_tcn = pd.read_csv('./data/csv/test_tcn.csv', usecols=['text'])
test_tcn = test_tcn['text']
test_tcn = test_tcn.apply(lambda t:OTHERS_PATTERN.sub(' ', t))

# %% [markdown]
# # Create dict for missing token in Vector from Google Translate (unused)

# %%
# from googletrans import Translator
# translator = Translator(service_urls=['translate.google.com'])

# def flatten_2d(old_list):
#     new_list = []
#     for sublist in old_list:
#         for item in sublist:
#             new_list.append(item)
#     return new_list

# def translate_token(token):
#     batch_token = []
#     for i in range(0, len(token), 250):
#         if i+250 >= len(token):
#             curr_batch = token[i:len(token)]
#         else:
#             curr_batch = token[i:i+250]
#         string_batch ='\n'.join(curr_batch)
#         batch_token.append(string_batch)

#     translated_token = []
#     for t in batch_token:
#         tr_object = translator.translate(t, src='zh-tw', dest='en')
#         curr_batch_translated = tr_object.text
#         curr_batch_translated = curr_batch_translated.split('\n')
#         translated_token = translated_token + curr_batch_translated

#     return translated_token

# def translate_missing_tokens(vec_src, val, test):
#     # check parrarel token exist
#     parrarel_tokens_path = './data/csv/parrarel_tokens.csv'
#     if os.path.isfile(parrarel_tokens_path):
#         print('Parrarel token detected!')
#         df_parrarel_tokens = pd.read_csv(parrarel_tokens_path)

#         parrarel_tokens = {}
#         for i in df_parrarel_tokens.index:
#             parrarel_tokens[df_parrarel_tokens.loc[i, 'zh']] = df_parrarel_tokens.loc[i, 'en'].lower()
#         return parrarel_tokens

#     # get all tokens
#     sentences = val.to_list() + test.to_list()
#     print('Total sentences:', len(sentences))
#     tokens = []
#     for s in sentences:
#         result = jieba.tokenize(s, mode='default')
#         token = [r[0] for r in result]
#         token = [t for t in token if t != '' and t != ' ']
#         tokens.append(token)
#     for s in sentences:
#         result = jieba.tokenize(s, mode='default')
#         token = [r[0] for r in result]
#         token = [t for t in token if t != '' and t != ' ']
#         tokens.append(token)
#     tokens = flatten_2d(tokens)
#     print('Total token:', len(tokens))
#     tokens = list(set(tokens))
#     print('Total unique token:', len(tokens))

#     # filter token
#     tokens = [t for t in tokens if re.sub(r'[^\u4e00-\u9fff]', '', t) != '']
#     print('Total CJK unicode token:', len(tokens))

#     # get missing tokens in vector
#     missing_tokens = []
#     for t in tokens:
#         try:
#             vec_src['word2id'][t]
#         except KeyError:
#             missing_tokens.append(t)
#     print('Total missing token:', len(missing_tokens))

#     # translate all missing token
#     print('Translating missing token...')
#     translated_token = translate_token(missing_tokens)

#     # save to file
#     df_parrarel_tokens = pd.DataFrame({
#         'zh': missing_tokens,
#         'en': translated_token
#     })
#     df_parrarel_tokens.to_csv(parrarel_tokens_path, index=False)
#     print('Parrarel token saved at', parrarel_tokens_path)

#     parrarel_tokens = {}
#     for i in df_parrarel_tokens.index:
#         parrarel_tokens[df_parrarel_tokens.loc[i, 'zh']] = df_parrarel_tokens.loc[i, 'en'].lower()

#     return parrarel_tokens

# %%
# parrarel_tokens = translate_missing_tokens(vec_ours_zh, val_tcn, test_tcn)

# %% [markdown]
# # Translate function

# %%
def translate_word_ours(word):
    word_id = vec_ours_zh['word2id'][word]
    english_ids = index_ours_ip['src2trg_id'][word_id]

    tr_word = vec_ours_en['id2word'][english_ids[0]]
    tr_dist = index_ours_ip['src2trg_dist'][word_id][0]

    tr_word = tr_word.lower()
    tr_word = re.sub(r'[^a-z]', '', tr_word)

    return tr_word, tr_dist

def translate_word_wiki(word):
    word_id = vec_wiki_zh['word2id'][word]
    english_ids = index_wiki_ip['src2trg_id'][word_id]

    tr_word = vec_wiki_en['id2word'][english_ids[0]]
    tr_dist = index_wiki_ip['src2trg_dist'][word_id][0]

    tr_word = tr_word.lower()
    tr_word = re.sub(r'[^a-z]', '', tr_word)

    return tr_word, tr_dist

def translate_word(word, *args):
    min_range_ours = args[0]
    min_range_wiki = args[1]
    priority = args[2]

    if word != re.sub(r'[^\u4e00-\u9fff]', '', word):
        return word
    else:
        try:
            tr_word_ours, tr_dist_ours = translate_word_ours(word)
        except KeyError:
            tr_word_ours = None
        except Exception as ex:
            tr_word_ours = None
            logging.exception(f'def translate_word_ours')
            logging.exception(f'Word: {word}')
            logging.exception(ex)


        try:
            tr_word_wiki, tr_dist_wiki = translate_word_wiki(word)
        except KeyError:
            tr_word_wiki = None
        except Exception as ex:
            tr_word_ours = None
            logging.exception(f'def translate_word_wiki')
            logging.exception(f'Word: {word}')
            logging.exception(ex)

        if tr_word_ours is None and tr_word_wiki is None:
            # zh word not in both vector 
            return word
        elif tr_word_ours is not None and tr_word_wiki is not None:
            # zh word in both vector
            if priority == 'wiki':
                if tr_dist_ours < min_range_ours:
                    return tr_word_ours
                elif tr_dist_wiki < min_range_wiki:
                    return tr_word_wiki
                else:
                    return word
            else: # ours
                if tr_dist_wiki < min_range_wiki:
                    return tr_word_wiki
                elif tr_dist_ours < min_range_ours:
                    return tr_word_ours
                else:
                    return word
        elif tr_word_ours is not None:
            # zh word only in ours vector
            if tr_dist_ours < min_range_ours:
                return tr_word_ours
            else:
                return word
        elif tr_word_wiki is not None:
            # zh word only in wiki vector
            if tr_dist_wiki < min_range_wiki:
                return tr_word_wiki
            else:
                return word
        else:
            logging.warning("Reached 'else' on def translate_word")
            return word


def tokenize_tcn(text, mode):
    try:
        result = jieba.tokenize(text, mode=mode)
        token = [r[0] for r in result]
    except Exception as ex:
        logging.exception(f'def tokenize_tcn')
        logging.exception(f'Text: {text}')
        logging.exception(ex)
        token = []
    finally:
        return token

def translate_sentence(sentence, tokenize_mode, *args):
    '''
    tokenize_mode = 'default' or 'search'
    '''
    # tokenize
    sentence = sentence.lower()
    token = tokenize_tcn(sentence, mode=tokenize_mode)
    token = [t for t in token if t != '' and t != ' ']

    # translate
    new_token = []
    for t in token:
        new_token.append(translate_word(t, *args))
    new_sentence = ' '.join(new_token)

    return new_sentence

# %% [markdown]
# # Translate & eval validation data

# %%
def eval(preds: List[str], refs: List[str]) -> float:
    """BLEU score computation.

    Strips all characters belonging to the unicode category "So".
    Tokenize with standard WMT "13a" tokenizer.
    Compute 4-BLEU.

    Args:
        preds (List[str]): List of translated texts.
        refs (List[str]): List of target reference texts.
    """
    preds = [OTHERS_PATTERN.sub(' ', text) for text in preds]
    refs = [OTHERS_PATTERN.sub(' ', text) for text in refs]
    return corpus_bleu(
        preds, [refs],
        lowercase=True,
        tokenize='13a',
        use_effective_order= False
    ).score

# %%
tokenize_mode = ['search', 'default']
min_range_ours = [v/10 for v in range(50, 450, 25)]
min_range_wiki = [v/100 for v in range(20, 75, 5)]
priority = ['wiki', 'ours']

translate_param = list(itertools.product(*[tokenize_mode, min_range_ours, min_range_wiki, priority]))
print('Total translate param permutation:', len(translate_param))

translated_val_tcn_list = []
for i in range(len(translate_param)):
    logging.info(f'Start translating validation data with param #{i}')
    logging.info(translate_param[i])
    translated_val_tcn = []
    for j in val_tcn.index:
        translated_val_tcn.append(
            translate_sentence(val_tcn[j], *translate_param[i])
        )
    translated_val_tcn_list.append(translated_val_tcn)
# Out:
# Building prefix dict from the default dictionary ...
# Total translate param permutation: 704
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.734 seconds.
# Prefix dict has been built successfully.

# %%
best_index = 0
best_bleu_score = 0
for i in range(len(translated_val_tcn_list)):
    bleu_score = eval(translated_val_tcn_list[i], val_en.to_list())
    logging.info(f'Bleu score for param {i}: {bleu_score}')
    print(f'Bleu score for param {i}: {bleu_score}')
    if bleu_score > best_bleu_score:
        best_index = i
        best_bleu_score = bleu_score
# Out:
# Bleu score for param 0: 19.12699204234897
# Bleu score for param 1: 19.12699204234897
# Bleu score for param 2: 19.130286443528398
# Bleu score for param 3: 19.130286443528398
# Bleu score for param 4: 19.132372990051543
# Bleu score for param 5: 19.132372990051543
# Bleu score for param 6: 19.147482372287325
# Bleu score for param 7: 19.147482372287325
# Bleu score for param 8: 19.461353188326058
# Bleu score for param 9: 19.461353188326058
# Bleu score for param 10: 20.123357104568186
# Bleu score for param 11: 20.123357104568186
# Bleu score for param 12: 21.92009976838403
# Bleu score for param 13: 21.92009976838403
# Bleu score for param 14: 24.869039012244265
# Bleu score for param 15: 24.870291387371598
# Bleu score for param 16: 26.599534607816775
# Bleu score for param 17: 26.600812111103497
# Bleu score for param 18: 27.022394390164663
# Bleu score for param 19: 27.02367912140134
# Bleu score for param 20: 27.16720939951434
# Bleu score for param 21: 27.168493203095164
# Bleu score for param 22: 19.12699204234897
# Bleu score for param 23: 19.12699204234897
# Bleu score for param 24: 19.130286443528398
# Bleu score for param 25: 19.130286443528398
# Bleu score for param 26: 19.132372990051543
# Bleu score for param 27: 19.132372990051543
# Bleu score for param 28: 19.147482372287325
# Bleu score for param 29: 19.147482372287325
# Bleu score for param 30: 19.461353188326058
# Bleu score for param 31: 19.461353188326058
# Bleu score for param 32: 20.056286576209693
# Bleu score for param 33: 20.123357104568186
# Bleu score for param 34: 21.713595455975327
# Bleu score for param 35: 21.92009976838403
# Bleu score for param 36: 23.796827462982183
# Bleu score for param 37: 24.870291387371598
# Bleu score for param 38: 25.05116685528125
# Bleu score for param 39: 26.600812111103497
# Bleu score for param 40: 25.417256257836005
# Bleu score for param 41: 27.02367912140134
# Bleu score for param 42: 25.55886086156062
# Bleu score for param 43: 27.168493203095164
# Bleu score for param 44: 19.12699204234897
# Bleu score for param 45: 19.12699204234897
# Bleu score for param 46: 19.129077998656857
# Bleu score for param 47: 19.130286443528398
# Bleu score for param 48: 19.13116441337453
# Bleu score for param 49: 19.132372990051543
# Bleu score for param 50: 19.1462734520949
# Bleu score for param 51: 19.147482372287325
# Bleu score for param 52: 19.418482230743823
# Bleu score for param 53: 19.461353188326058
# Bleu score for param 54: 19.84796282200832
# Bleu score for param 55: 20.123357104568186
# Bleu score for param 56: 20.802231545254948
# Bleu score for param 57: 21.92009976838403
# Bleu score for param 58: 22.240294954374335
# Bleu score for param 59: 24.870291387371598
# Bleu score for param 60: 22.80445295964444
# Bleu score for param 61: 26.600812111103497
# Bleu score for param 62: 22.90505439950657
# Bleu score for param 63: 27.02367912140134
# Bleu score for param 64: 22.909755973689716
# Bleu score for param 65: 27.168493203095164
# Bleu score for param 66: 19.12699204234897
# Bleu score for param 67: 19.12699204234897
# Bleu score for param 68: 19.129077998656857
# Bleu score for param 69: 19.130286443528398
# Bleu score for param 70: 19.13116441337453
# Bleu score for param 71: 19.132372990051543
# Bleu score for param 72: 19.1462734520949
# Bleu score for param 73: 19.147482372287325
# Bleu score for param 74: 19.382501491641673
# Bleu score for param 75: 19.461353188326058
# Bleu score for param 76: 19.633203125597454
# Bleu score for param 77: 20.123357104568186
# Bleu score for param 78: 20.062016860621615
# Bleu score for param 79: 21.92009976838403
# Bleu score for param 80: 20.73442581347289
# Bleu score for param 81: 24.870291387371598
# Bleu score for param 82: 21.082492605241228
# Bleu score for param 83: 26.600812111103497
# Bleu score for param 84: 21.144716544015886
# Bleu score for param 85: 27.02367912140134
# Bleu score for param 86: 21.144716544015886
# Bleu score for param 87: 27.168493203095164
# Bleu score for param 88: 19.129077998656857
# Bleu score for param 89: 19.129077998656857
# Bleu score for param 90: 19.13116441337453
# Bleu score for param 91: 19.132372990051543
# Bleu score for param 92: 19.13116441337453
# Bleu score for param 93: 19.134459995165695
# Bleu score for param 94: 19.13863538177638
# Bleu score for param 95: 19.149572182314266
# Bleu score for param 96: 19.292853739091335
# Bleu score for param 97: 19.463480082190554
# Bleu score for param 98: 19.417793389567695
# Bleu score for param 99: 20.123357104568186
# Bleu score for param 100: 19.593601138054296
# Bleu score for param 101: 21.92009976838403
# Bleu score for param 102: 19.781659180165384
# Bleu score for param 103: 24.870291387371598
# Bleu score for param 104: 20.046318890863976
# Bleu score for param 105: 26.600812111103497
# Bleu score for param 106: 20.099949328538965
# Bleu score for param 107: 27.02367912140134
# Bleu score for param 108: 20.099949328538965
# Bleu score for param 109: 27.168493203095164
# Bleu score for param 110: 19.129077998656857
# Bleu score for param 111: 19.129077998656857
# Bleu score for param 112: 19.13116441337453
# Bleu score for param 113: 19.132372990051543
# Bleu score for param 114: 19.13116441337453
# Bleu score for param 115: 19.134459995165695
# Bleu score for param 116: 19.13654745902317
# Bleu score for param 117: 19.149572182314266
# Bleu score for param 118: 19.197833040353533
# Bleu score for param 119: 19.463480082190554
# Bleu score for param 120: 19.27277126187176
# Bleu score for param 121: 20.123357104568186
# Bleu score for param 122: 19.355946348491564
# Bleu score for param 123: 21.92009976838403
# Bleu score for param 124: 19.420991477302778
# Bleu score for param 125: 24.870291387371598
# Bleu score for param 126: 19.587103183517126
# Bleu score for param 127: 26.600812111103497
# Bleu score for param 128: 19.64068151423008
# Bleu score for param 129: 27.02367912140134
# Bleu score for param 130: 19.64068151423008
# Bleu score for param 131: 27.168493203095164
# Bleu score for param 132: 19.129077998656857
# Bleu score for param 133: 19.129077998656857
# Bleu score for param 134: 19.13116441337453
# Bleu score for param 135: 19.132372990051543
# Bleu score for param 136: 19.13116441337453
# Bleu score for param 137: 19.134459995165695
# Bleu score for param 138: 19.134459995165695
# Bleu score for param 139: 19.149572182314266
# Bleu score for param 140: 19.170351775752007
# Bleu score for param 141: 19.463480082190554
# Bleu score for param 142: 19.23864044273473
# Bleu score for param 143: 20.123357104568186
# Bleu score for param 144: 19.281061683128275
# Bleu score for param 145: 21.92009976838403
# Bleu score for param 146: 19.298685555551014
# Bleu score for param 147: 24.870291387371598
# Bleu score for param 148: 19.33622427325249
# Bleu score for param 149: 26.600812111103497
# Bleu score for param 150: 19.3482440616593
# Bleu score for param 151: 27.02367912140134
# Bleu score for param 152: 19.3482440616593
# Bleu score for param 153: 27.168493203095164
# Bleu score for param 154: 19.129077998656857
# Bleu score for param 155: 19.129077998656857
# Bleu score for param 156: 19.13116441337453
# Bleu score for param 157: 19.132372990051543
# Bleu score for param 158: 19.13116441337453
# Bleu score for param 159: 19.134459995165695
# Bleu score for param 160: 19.134459995165695
# Bleu score for param 161: 19.149572182314266
# Bleu score for param 162: 19.153099860599433
# Bleu score for param 163: 19.463480082190554
# Bleu score for param 164: 19.21308270382463
# Bleu score for param 165: 20.123357104568186
# Bleu score for param 166: 19.232509802986037
# Bleu score for param 167: 21.92009976838403
# Bleu score for param 168: 19.23854732054113
# Bleu score for param 169: 24.870291387371598
# Bleu score for param 170: 19.24578484667694
# Bleu score for param 171: 26.600812111103497
# Bleu score for param 172: 19.255422198142924
# Bleu score for param 173: 27.02367912140134
# Bleu score for param 174: 19.255422198142924
# Bleu score for param 175: 27.168493203095164
# Bleu score for param 176: 19.129077998656857
# Bleu score for param 177: 19.129077998656857
# Bleu score for param 178: 19.13116441337453
# Bleu score for param 179: 19.132372990051543
# Bleu score for param 180: 19.13116441337453
# Bleu score for param 181: 19.134459995165695
# Bleu score for param 182: 19.134459995165695
# Bleu score for param 183: 19.149572182314266
# Bleu score for param 184: 19.143863736685873
# Bleu score for param 185: 19.463480082190554
# Bleu score for param 186: 19.172944696301048
# Bleu score for param 187: 20.123357104568186
# Bleu score for param 188: 19.18123706161705
# Bleu score for param 189: 21.92009976838403
# Bleu score for param 190: 19.186064352061255
# Bleu score for param 191: 24.870291387371598
# Bleu score for param 192: 19.193298462949556
# Bleu score for param 193: 26.600812111103497
# Bleu score for param 194: 19.202931238108697
# Bleu score for param 195: 27.02367912140134
# Bleu score for param 196: 19.202931238108697
# Bleu score for param 197: 27.168493203095164
# Bleu score for param 198: 19.129077998656857
# Bleu score for param 199: 19.129077998656857
# Bleu score for param 200: 19.13116441337453
# Bleu score for param 201: 19.132372990051543
# Bleu score for param 202: 19.13116441337453
# Bleu score for param 203: 19.134459995165695
# Bleu score for param 204: 19.133251286654243
# Bleu score for param 205: 19.149572182314266
# Bleu score for param 206: 19.142655350141315
# Bleu score for param 207: 19.463480082190554
# Bleu score for param 208: 19.171736304734434
# Bleu score for param 209: 20.123357104568186
# Bleu score for param 210: 19.177614200550465
# Bleu score for param 211: 21.92009976838403
# Bleu score for param 212: 19.1788220490339
# Bleu score for param 213: 24.870291387371598
# Bleu score for param 214: 19.18123706161705
# Bleu score for param 215: 26.600812111103497
# Bleu score for param 216: 19.19088800155662
# Bleu score for param 217: 27.02367912140134
# Bleu score for param 218: 19.19088800155662
# Bleu score for param 219: 27.168493203095164
# Bleu score for param 220: 19.129077998656857
# Bleu score for param 221: 19.129077998656857
# Bleu score for param 222: 19.13116441337453
# Bleu score for param 223: 19.132372990051543
# Bleu score for param 224: 19.13116441337453
# Bleu score for param 225: 19.134459995165695
# Bleu score for param 226: 19.133251286654243
# Bleu score for param 227: 19.149572182314266
# Bleu score for param 228: 19.142655350141315
# Bleu score for param 229: 19.463480082190554
# Bleu score for param 230: 19.163926552218125
# Bleu score for param 231: 20.123357104568186
# Bleu score for param 232: 19.16859629746353
# Bleu score for param 233: 21.92009976838403
# Bleu score for param 234: 19.16859629746353
# Bleu score for param 235: 24.870291387371598
# Bleu score for param 236: 19.16859629746353
# Bleu score for param 237: 26.600812111103497
# Bleu score for param 238: 19.178257891406638
# Bleu score for param 239: 27.02367912140134
# Bleu score for param 240: 19.178257891406638
# Bleu score for param 241: 27.168493203095164
# Bleu score for param 242: 19.129077998656857
# Bleu score for param 243: 19.129077998656857
# Bleu score for param 244: 19.13116441337453
# Bleu score for param 245: 19.132372990051543
# Bleu score for param 246: 19.13116441337453
# Bleu score for param 247: 19.134459995165695
# Bleu score for param 248: 19.133251286654243
# Bleu score for param 249: 19.149572182314266
# Bleu score for param 250: 19.142655350141315
# Bleu score for param 251: 19.463480082190554
# Bleu score for param 252: 19.163926552218125
# Bleu score for param 253: 20.123357104568186
# Bleu score for param 254: 19.16738757050999
# Bleu score for param 255: 21.92009976838403
# Bleu score for param 256: 19.16738757050999
# Bleu score for param 257: 24.870291387371598
# Bleu score for param 258: 19.16738757050999
# Bleu score for param 259: 26.600812111103497
# Bleu score for param 260: 19.16738757050999
# Bleu score for param 261: 27.02367912140134
# Bleu score for param 262: 19.16738757050999
# Bleu score for param 263: 27.168493203095164
# Bleu score for param 264: 19.129077998656857
# Bleu score for param 265: 19.129077998656857
# Bleu score for param 266: 19.13116441337453
# Bleu score for param 267: 19.132372990051543
# Bleu score for param 268: 19.13116441337453
# Bleu score for param 269: 19.134459995165695
# Bleu score for param 270: 19.133251286654243
# Bleu score for param 271: 19.149572182314266
# Bleu score for param 272: 19.142655350141315
# Bleu score for param 273: 19.463480082190554
# Bleu score for param 274: 19.150130583463294
# Bleu score for param 275: 20.123357104568186
# Bleu score for param 276: 19.150130583463294
# Bleu score for param 277: 21.92009976838403
# Bleu score for param 278: 19.150130583463294
# Bleu score for param 279: 24.870291387371598
# Bleu score for param 280: 19.150130583463294
# Bleu score for param 281: 26.600812111103497
# Bleu score for param 282: 19.150130583463294
# Bleu score for param 283: 27.02367912140134
# Bleu score for param 284: 19.150130583463294
# Bleu score for param 285: 27.168493203095164
# Bleu score for param 286: 19.129077998656857
# Bleu score for param 287: 19.129077998656857
# Bleu score for param 288: 19.13116441337453
# Bleu score for param 289: 19.132372990051543
# Bleu score for param 290: 19.13116441337453
# Bleu score for param 291: 19.134459995165695
# Bleu score for param 292: 19.133251286654243
# Bleu score for param 293: 19.149572182314266
# Bleu score for param 294: 19.142655350141315
# Bleu score for param 295: 19.463480082190554
# Bleu score for param 296: 19.150130583463294
# Bleu score for param 297: 20.123357104568186
# Bleu score for param 298: 19.150130583463294
# Bleu score for param 299: 21.92009976838403
# Bleu score for param 300: 19.150130583463294
# Bleu score for param 301: 24.870291387371598
# Bleu score for param 302: 19.150130583463294
# Bleu score for param 303: 26.600812111103497
# Bleu score for param 304: 19.150130583463294
# Bleu score for param 305: 27.02367912140134
# Bleu score for param 306: 19.150130583463294
# Bleu score for param 307: 27.168493203095164
# Bleu score for param 308: 19.129077998656857
# Bleu score for param 309: 19.129077998656857
# Bleu score for param 310: 19.13116441337453
# Bleu score for param 311: 19.132372990051543
# Bleu score for param 312: 19.13116441337453
# Bleu score for param 313: 19.134459995165695
# Bleu score for param 314: 19.133251286654243
# Bleu score for param 315: 19.149572182314266
# Bleu score for param 316: 19.142655350141315
# Bleu score for param 317: 19.463480082190554
# Bleu score for param 318: 19.150130583463294
# Bleu score for param 319: 20.123357104568186
# Bleu score for param 320: 19.150130583463294
# Bleu score for param 321: 21.92009976838403
# Bleu score for param 322: 19.150130583463294
# Bleu score for param 323: 24.870291387371598
# Bleu score for param 324: 19.150130583463294
# Bleu score for param 325: 26.600812111103497
# Bleu score for param 326: 19.150130583463294
# Bleu score for param 327: 27.02367912140134
# Bleu score for param 328: 19.150130583463294
# Bleu score for param 329: 27.168493203095164
# Bleu score for param 330: 19.129077998656857
# Bleu score for param 331: 19.129077998656857
# Bleu score for param 332: 19.13116441337453
# Bleu score for param 333: 19.132372990051543
# Bleu score for param 334: 19.13116441337453
# Bleu score for param 335: 19.134459995165695
# Bleu score for param 336: 19.133251286654243
# Bleu score for param 337: 19.149572182314266
# Bleu score for param 338: 19.142655350141315
# Bleu score for param 339: 19.463480082190554
# Bleu score for param 340: 19.150130583463294
# Bleu score for param 341: 20.123357104568186
# Bleu score for param 342: 19.150130583463294
# Bleu score for param 343: 21.92009976838403
# Bleu score for param 344: 19.150130583463294
# Bleu score for param 345: 24.870291387371598
# Bleu score for param 346: 19.150130583463294
# Bleu score for param 347: 26.600812111103497
# Bleu score for param 348: 19.150130583463294
# Bleu score for param 349: 27.02367912140134
# Bleu score for param 350: 19.150130583463294
# Bleu score for param 351: 27.168493203095164
# Bleu score for param 352: 19.718438908801865
# Bleu score for param 353: 19.718438908801865
# Bleu score for param 354: 19.721902722530093
# Bleu score for param 355: 19.721902722530093
# Bleu score for param 356: 19.72412136258323
# Bleu score for param 357: 19.72412136258323
# Bleu score for param 358: 19.74003639621215
# Bleu score for param 359: 19.74003639621215
# Bleu score for param 360: 20.05819905388844
# Bleu score for param 361: 20.05819905388844
# Bleu score for param 362: 20.74255984085246
# Bleu score for param 363: 20.74255984085246
# Bleu score for param 364: 22.5399570244419
# Bleu score for param 365: 22.5399570244419
# Bleu score for param 366: 25.44506171293407
# Bleu score for param 367: 25.446356396415148
# Bleu score for param 368: 26.96320492382726
# Bleu score for param 369: 26.964513467905448
# Bleu score for param 370: 27.326928269516806
# Bleu score for param 371: 27.328241211998762
# Bleu score for param 372: 27.473978567492207
# Bleu score for param 373: 27.475290506877922
# Bleu score for param 374: 19.718438908801865
# Bleu score for param 375: 19.718438908801865
# Bleu score for param 376: 19.721902722530093
# Bleu score for param 377: 19.721902722530093
# Bleu score for param 378: 19.72412136258323
# Bleu score for param 379: 19.72412136258323
# Bleu score for param 380: 19.74003639621215
# Bleu score for param 381: 19.74003639621215
# Bleu score for param 382: 20.05819905388844
# Bleu score for param 383: 20.05819905388844
# Bleu score for param 384: 20.671617211490265
# Bleu score for param 385: 20.74255984085246
# Bleu score for param 386: 22.32376939290991
# Bleu score for param 387: 22.5399570244419
# Bleu score for param 388: 24.490325260099134
# Bleu score for param 389: 25.446356396415148
# Bleu score for param 390: 25.667258792009214
# Bleu score for param 391: 26.964513467905448
# Bleu score for param 392: 25.984206029873704
# Bleu score for param 393: 27.328241211998762
# Bleu score for param 394: 26.12952713993648
# Bleu score for param 395: 27.475290506877922
# Bleu score for param 396: 19.718438908801865
# Bleu score for param 397: 19.718438908801865
# Bleu score for param 398: 19.720656905732085
# Bleu score for param 399: 19.721902722530093
# Bleu score for param 400: 19.722875405635506
# Bleu score for param 401: 19.72412136258323
# Bleu score for param 402: 19.73879006376308
# Bleu score for param 403: 19.74003639621215
# Bleu score for param 404: 20.02001214189118
# Bleu score for param 405: 20.05819905388844
# Bleu score for param 406: 20.462135701804495
# Bleu score for param 407: 20.74255984085246
# Bleu score for param 408: 21.43167483102894
# Bleu score for param 409: 22.5399570244419
# Bleu score for param 410: 22.928419962194074
# Bleu score for param 411: 25.446356396415148
# Bleu score for param 412: 23.508866509099633
# Bleu score for param 413: 26.964513467905448
# Bleu score for param 414: 23.609087505096845
# Bleu score for param 415: 27.328241211998762
# Bleu score for param 416: 23.613945711450015
# Bleu score for param 417: 27.475290506877922
# Bleu score for param 418: 19.718438908801865
# Bleu score for param 419: 19.718438908801865
# Bleu score for param 420: 19.720656905732085
# Bleu score for param 421: 19.721902722530093
# Bleu score for param 422: 19.722875405635506
# Bleu score for param 423: 19.72412136258323
# Bleu score for param 424: 19.73879006376308
# Bleu score for param 425: 19.74003639621215
# Bleu score for param 426: 19.982851205798255
# Bleu score for param 427: 20.05819905388844
# Bleu score for param 428: 20.241404406759482
# Bleu score for param 429: 20.74255984085246
# Bleu score for param 430: 20.67049792483672
# Bleu score for param 431: 22.5399570244419
# Bleu score for param 432: 21.37593778402206
# Bleu score for param 433: 25.446356396415148
# Bleu score for param 434: 21.73253028742574
# Bleu score for param 435: 26.964513467905448
# Bleu score for param 436: 21.7967409206433
# Bleu score for param 437: 27.328241211998762
# Bleu score for param 438: 21.7967409206433
# Bleu score for param 439: 27.475290506877922
# Bleu score for param 440: 19.720656905732085
# Bleu score for param 441: 19.720656905732085
# Bleu score for param 442: 19.722875405635506
# Bleu score for param 443: 19.72412136258323
# Bleu score for param 444: 19.722875405635506
# Bleu score for param 445: 19.726340505813802
# Bleu score for param 446: 19.73078030249755
# Bleu score for param 447: 19.742258599879992
# Bleu score for param 448: 19.89226947226722
# Bleu score for param 449: 20.0604599182001
# Bleu score for param 450: 20.02054101101252
# Bleu score for param 451: 20.74255984085246
# Bleu score for param 452: 20.195217123273633
# Bleu score for param 453: 22.5399570244419
# Bleu score for param 454: 20.4011277713971
# Bleu score for param 455: 25.446356396415148
# Bleu score for param 456: 20.672690952587455
# Bleu score for param 457: 26.964513467905448
# Bleu score for param 458: 20.728022637889953
# Bleu score for param 459: 27.328241211998762
# Bleu score for param 460: 20.728022637889953
# Bleu score for param 461: 27.475290506877922
# Bleu score for param 462: 19.720656905732085
# Bleu score for param 463: 19.720656905732085
# Bleu score for param 464: 19.722875405635506
# Bleu score for param 465: 19.72412136258323
# Bleu score for param 466: 19.722875405635506
# Bleu score for param 467: 19.726340505813802
# Bleu score for param 468: 19.728560152394365
# Bleu score for param 469: 19.742258599879992
# Bleu score for param 470: 19.789318263490976
# Bleu score for param 471: 20.0604599182001
# Bleu score for param 472: 19.865806653457327
# Bleu score for param 473: 20.74255984085246
# Bleu score for param 474: 19.946868999271707
# Bleu score for param 475: 22.5399570244419
# Bleu score for param 476: 20.028103760600537
# Bleu score for param 477: 25.446356396415148
# Bleu score for param 478: 20.20169913375536
# Bleu score for param 479: 26.964513467905448
# Bleu score for param 480: 20.256957496612056
# Bleu score for param 481: 27.328241211998762
# Bleu score for param 482: 20.256957496612056
# Bleu score for param 483: 27.475290506877922
# Bleu score for param 484: 19.720656905732085
# Bleu score for param 485: 19.720656905732085
# Bleu score for param 486: 19.722875405635506
# Bleu score for param 487: 19.72412136258323
# Bleu score for param 488: 19.722875405635506
# Bleu score for param 489: 19.726340505813802
# Bleu score for param 490: 19.726340505813802
# Bleu score for param 491: 19.742258599879992
# Bleu score for param 492: 19.754894303981064
# Bleu score for param 493: 20.0604599182001
# Bleu score for param 494: 19.8220603346463
# Bleu score for param 495: 20.74255984085246
# Bleu score for param 496: 19.86357470587944
# Bleu score for param 497: 22.5399570244419
# Bleu score for param 498: 19.89589530629245
# Bleu score for param 499: 25.446356396415148
# Bleu score for param 500: 19.936938813879532
# Bleu score for param 501: 26.964513467905448
# Bleu score for param 502: 19.94934744552495
# Bleu score for param 503: 27.328241211998762
# Bleu score for param 504: 19.94934744552495
# Bleu score for param 505: 27.475290506877922
# Bleu score for param 506: 19.720656905732085
# Bleu score for param 507: 19.720656905732085
# Bleu score for param 508: 19.722875405635506
# Bleu score for param 509: 19.72412136258323
# Bleu score for param 510: 19.722875405635506
# Bleu score for param 511: 19.726340505813802
# Bleu score for param 512: 19.726340505813802
# Bleu score for param 513: 19.742258599879992
# Bleu score for param 514: 19.738355515549678
# Bleu score for param 515: 20.0604599182001
# Bleu score for param 516: 19.796957920319308
# Bleu score for param 517: 20.74255984085246
# Bleu score for param 518: 19.81469593035232
# Bleu score for param 519: 22.5399570244419
# Bleu score for param 520: 19.834987884491003
# Bleu score for param 521: 25.446356396415148
# Bleu score for param 522: 19.842457284377968
# Bleu score for param 523: 26.964513467905448
# Bleu score for param 524: 19.852403381377826
# Bleu score for param 525: 27.328241211998762
# Bleu score for param 526: 19.852403381377826
# Bleu score for param 527: 27.475290506877922
# Bleu score for param 528: 19.720656905732085
# Bleu score for param 529: 19.720656905732085
# Bleu score for param 530: 19.722875405635506
# Bleu score for param 531: 19.72412136258323
# Bleu score for param 532: 19.722875405635506
# Bleu score for param 533: 19.726340505813802
# Bleu score for param 534: 19.726340505813802
# Bleu score for param 535: 19.742258599879992
# Bleu score for param 536: 19.728831991876216
# Bleu score for param 537: 20.0604599182001
# Bleu score for param 538: 19.759145959711496
# Bleu score for param 539: 20.74255984085246
# Bleu score for param 540: 19.766449898932912
# Bleu score for param 541: 22.5399570244419
# Bleu score for param 542: 19.785489656650626
# Bleu score for param 543: 25.446356396415148
# Bleu score for param 544: 19.792953533359427
# Bleu score for param 545: 26.964513467905448
# Bleu score for param 546: 19.80289225280205
# Bleu score for param 547: 27.328241211998762
# Bleu score for param 548: 19.80289225280205
# Bleu score for param 549: 27.475290506877922
# Bleu score for param 550: 19.720656905732085
# Bleu score for param 551: 19.720656905732085
# Bleu score for param 552: 19.722875405635506
# Bleu score for param 553: 19.72412136258323
# Bleu score for param 554: 19.722875405635506
# Bleu score for param 555: 19.726340505813802
# Bleu score for param 556: 19.725094408684587
# Bleu score for param 557: 19.742258599879992
# Bleu score for param 558: 19.7275863668429
# Bleu score for param 559: 20.0604599182001
# Bleu score for param 560: 19.757900308265768
# Bleu score for param 561: 20.74255984085246
# Bleu score for param 562: 19.76395995117313
# Bleu score for param 563: 22.5399570244419
# Bleu score for param 564: 19.76520504268094
# Bleu score for param 565: 25.446356396415148
# Bleu score for param 566: 19.767694520032737
# Bleu score for param 567: 26.964513467905448
# Bleu score for param 568: 19.777643035773533
# Bleu score for param 569: 27.328241211998762
# Bleu score for param 570: 19.777643035773533
# Bleu score for param 571: 27.475290506877922
# Bleu score for param 572: 19.720656905732085
# Bleu score for param 573: 19.720656905732085
# Bleu score for param 574: 19.722875405635506
# Bleu score for param 575: 19.72412136258323
# Bleu score for param 576: 19.722875405635506
# Bleu score for param 577: 19.726340505813802
# Bleu score for param 578: 19.725094408684587
# Bleu score for param 579: 19.742258599879992
# Bleu score for param 580: 19.7275863668429
# Bleu score for param 581: 20.0604599182001
# Bleu score for param 582: 19.74971535708486
# Bleu score for param 583: 20.74255984085246
# Bleu score for param 584: 19.754529564038748
# Bleu score for param 585: 22.5399570244419
# Bleu score for param 586: 19.754529564038748
# Bleu score for param 587: 25.446356396415148
# Bleu score for param 588: 19.754529564038748
# Bleu score for param 589: 26.964513467905448
# Bleu score for param 590: 19.76448899728245
# Bleu score for param 591: 27.328241211998762
# Bleu score for param 592: 19.76448899728245
# Bleu score for param 593: 27.475290506877922
# Bleu score for param 594: 19.720656905732085
# Bleu score for param 595: 19.720656905732085
# Bleu score for param 596: 19.722875405635506
# Bleu score for param 597: 19.72412136258323
# Bleu score for param 598: 19.722875405635506
# Bleu score for param 599: 19.726340505813802
# Bleu score for param 600: 19.725094408684587
# Bleu score for param 601: 19.742258599879992
# Bleu score for param 602: 19.7275863668429
# Bleu score for param 603: 20.0604599182001
# Bleu score for param 604: 19.74971535708486
# Bleu score for param 605: 20.74255984085246
# Bleu score for param 606: 19.75328357522407
# Bleu score for param 607: 22.5399570244419
# Bleu score for param 608: 19.75328357522407
# Bleu score for param 609: 25.446356396415148
# Bleu score for param 610: 19.75328357522407
# Bleu score for param 611: 26.964513467905448
# Bleu score for param 612: 19.75328357522407
# Bleu score for param 613: 27.328241211998762
# Bleu score for param 614: 19.75328357522407
# Bleu score for param 615: 27.475290506877922
# Bleu score for param 616: 19.720656905732085
# Bleu score for param 617: 19.720656905732085
# Bleu score for param 618: 19.722875405635506
# Bleu score for param 619: 19.72412136258323
# Bleu score for param 620: 19.722875405635506
# Bleu score for param 621: 19.726340505813802
# Bleu score for param 622: 19.725094408684587
# Bleu score for param 623: 19.742258599879992
# Bleu score for param 624: 19.7275863668429
# Bleu score for param 625: 20.0604599182001
# Bleu score for param 626: 19.735493283589975
# Bleu score for param 627: 20.74255984085246
# Bleu score for param 628: 19.735493283589975
# Bleu score for param 629: 22.5399570244419
# Bleu score for param 630: 19.735493283589975
# Bleu score for param 631: 25.446356396415148
# Bleu score for param 632: 19.735493283589975
# Bleu score for param 633: 26.964513467905448
# Bleu score for param 634: 19.735493283589975
# Bleu score for param 635: 27.328241211998762
# Bleu score for param 636: 19.735493283589975
# Bleu score for param 637: 27.475290506877922
# Bleu score for param 638: 19.720656905732085
# Bleu score for param 639: 19.720656905732085
# Bleu score for param 640: 19.722875405635506
# Bleu score for param 641: 19.72412136258323
# Bleu score for param 642: 19.722875405635506
# Bleu score for param 643: 19.726340505813802
# Bleu score for param 644: 19.725094408684587
# Bleu score for param 645: 19.742258599879992
# Bleu score for param 646: 19.7275863668429
# Bleu score for param 647: 20.0604599182001
# Bleu score for param 648: 19.735493283589975
# Bleu score for param 649: 20.74255984085246
# Bleu score for param 650: 19.735493283589975
# Bleu score for param 651: 22.5399570244419
# Bleu score for param 652: 19.735493283589975
# Bleu score for param 653: 25.446356396415148
# Bleu score for param 654: 19.735493283589975
# Bleu score for param 655: 26.964513467905448
# Bleu score for param 656: 19.735493283589975
# Bleu score for param 657: 27.328241211998762
# Bleu score for param 658: 19.735493283589975
# Bleu score for param 659: 27.475290506877922
# Bleu score for param 660: 19.720656905732085
# Bleu score for param 661: 19.720656905732085
# Bleu score for param 662: 19.722875405635506
# Bleu score for param 663: 19.72412136258323
# Bleu score for param 664: 19.722875405635506
# Bleu score for param 665: 19.726340505813802
# Bleu score for param 666: 19.725094408684587
# Bleu score for param 667: 19.742258599879992
# Bleu score for param 668: 19.7275863668429
# Bleu score for param 669: 20.0604599182001
# Bleu score for param 670: 19.735493283589975
# Bleu score for param 671: 20.74255984085246
# Bleu score for param 672: 19.735493283589975
# Bleu score for param 673: 22.5399570244419
# Bleu score for param 674: 19.735493283589975
# Bleu score for param 675: 25.446356396415148
# Bleu score for param 676: 19.735493283589975
# Bleu score for param 677: 26.964513467905448
# Bleu score for param 678: 19.735493283589975
# Bleu score for param 679: 27.328241211998762
# Bleu score for param 680: 19.735493283589975
# Bleu score for param 681: 27.475290506877922
# Bleu score for param 682: 19.720656905732085
# Bleu score for param 683: 19.720656905732085
# Bleu score for param 684: 19.722875405635506
# Bleu score for param 685: 19.72412136258323
# Bleu score for param 686: 19.722875405635506
# Bleu score for param 687: 19.726340505813802
# Bleu score for param 688: 19.725094408684587
# Bleu score for param 689: 19.742258599879992
# Bleu score for param 690: 19.7275863668429
# Bleu score for param 691: 20.0604599182001
# Bleu score for param 692: 19.735493283589975
# Bleu score for param 693: 20.74255984085246
# Bleu score for param 694: 19.735493283589975
# Bleu score for param 695: 22.5399570244419
# Bleu score for param 696: 19.735493283589975
# Bleu score for param 697: 25.446356396415148
# Bleu score for param 698: 19.735493283589975
# Bleu score for param 699: 26.964513467905448
# Bleu score for param 700: 19.735493283589975
# Bleu score for param 701: 27.328241211998762
# Bleu score for param 702: 19.735493283589975
# Bleu score for param 703: 27.475290506877922

# %% [markdown]
# # Translate test data

# %%
print(f'Start translating test data with best param #{best_index}')
print(translate_param[best_index])

logging.info(f'Start translating test data with best param #{best_index}')
logging.info(translate_param[best_index])

translated_test_tcn = []

for i in test_tcn.index:
    translated_test_tcn.append(translate_sentence(test_tcn[i], *translate_param[best_index]))
# Out:
# Start translating test data with best param #373
# ('default', 5.0, 0.7, 'ours')

# %%
df_submission = pd.DataFrame(translated_test_tcn, columns=['translation_output'])
df_submission
# Out:
#                                      translation_output
# 0     【 polarstar 】 美麗諾 wool warmth stockings 『 淺灰 』...
# 1     sweet crystal ~ natural crystal divination 珠手 ...
# 2                                     粉晶 hexagon 柱純 銀項
# 3        3m scotch vhb 超強力 hexbreaker  - outdoor  v1808
# 4                    lights exclusive discounts * 4 box
# ...                                                 ...
# 9995  rains backpack  backpack briefcase 筆電包 denmark...
# 9996        airwalk wickies 童鞋 blue 中童 a823230180 no002
# 9997  norns 【 disney 5000mah action electrict ( 泰瑞 c...
# 9998  derwent 達爾文設    arsenic  deluxe 12  ( 6b - 4h ...
# 9999      borofone be11 movement 磁吸 wireless headphones
#
# [10000 rows x 1 columns]

# %%
df_submission.to_csv(f'./submission_{START_DATETIME}.csv', index=False)
